# %%
import matplotlib.pyplot as plt 
import networkx as nx

# %%
G = nx.Graph()
G.add_nodes_from([i for i in range(9)])
G.add_weighted_edges_from((
    (0, 1, 4), (0, 7, 8),
    (1, 7, 11), (1, 2, 8),
    (2, 3, 7), (2, 5, 4), (2, 8, 2),
    (3, 4, 9), (3, 5, 14),
    (4, 5, 10),
    (5, 6, 2),
    (6, 7, 1), (6, 8, 6),
    (7, 8, 7)
))
pos = (
    (-0.5, 0.5), (0, 1), (1, 1), (2, 1), (2.5, 0.5),
    (2, 0), (1, 0), (0, 0), (0.5, 0.5)
)
labels = nx.get_edge_attributes(G, 'weight')
nx.draw(G, pos, node_size=1000, with_labels=True)
nx.draw_networkx_edge_labels(G, pos, edge_labels=labels)
# Out:
# {(0, 1): Text(-0.25, 0.75, '4'),
#  (0, 7): Text(-0.25, 0.25, '8'),
#  (1, 7): Text(0.0, 0.5, '11'),
#  (1, 2): Text(0.5, 1.0, '8'),
#  (2, 3): Text(1.5, 1.0, '7'),
#  (2, 5): Text(1.5, 0.5, '4'),
#  (2, 8): Text(0.75, 0.75, '2'),
#  (3, 4): Text(2.25, 0.75, '9'),
#  (3, 5): Text(2.0, 0.5, '14'),
#  (4, 5): Text(2.25, 0.25, '10'),
#  (5, 6): Text(1.5, 0.0, '2'),
#  (6, 7): Text(0.5, 0.0, '1'),
#  (6, 8): Text(0.75, 0.25, '6'),
#  (7, 8): Text(0.25, 0.25, '7')}
