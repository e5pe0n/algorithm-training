# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
n = [4, 8, 16, 32]
cut_rod_cpp_d = [709, 4969, 957587, 55477300831]
cut_rod_py_d = [15019, 169146, 44874848, 2411756774675]
plt.plot(n, rod_cut_cpp_d, marker='o', label='cpp')
plt.plot(n, rod_cut_py_d, marker='o', label='python')
plt.yscale('log')
plt.title('cut rod (log scale)')
plt.xlabel('n')
plt.ylabel('duration[ns]')
plt.grid()
plt.legend()

# %%
m_cut_rod_cpp_d = [427, 921, 2119, 5450]
b_cut_rod_cpp_d = [444, 815, 1839, 5934]

m_cut_rod_py_d = [6666, 9914, 24518, 82062]
b_cut_rod_py_d = [7223, 16622, 20201, 60926]

# %%
plt.plot(n, m_cut_rod_cpp_d, marker='o', label='cpp')
plt.plot(n, m_cut_rod_py_d, marker='o', label='python')
plt.title('memoized cut rod aux')
plt.xlabel('n')
plt.ylabel('duration[ns]')
plt.grid()
plt.legend()

# %%
plt.plot(n, b_cut_rod_cpp_d, marker='o', label='cpp')
plt.plot(n, b_cut_rod_py_d, marker='o', label='python')
plt.title('bottom up cut rod')
plt.xlabel('n')
plt.ylabel('duration[ns]')
plt.grid()
plt.legend()

# %%
plt.plot(n, cut_rod_cpp_d, marker='o', label='cut_rod')
plt.plot(n, m_cut_rod_cpp_d, marker='o', label='memoized_cut_rod_aux')
plt.plot(n, b_cut_rod_cpp_d, marker='o', label='bottom_up_cut_rod')
plt.yscale('log')
plt.title('cpp (log scale)')
plt.xlabel('n')
plt.ylabel('duration[ns]')
plt.grid()
plt.legend()

# %%
plt.plot(n, cut_rod_py_d, marker='o', label='cut_rod')
plt.plot(n, m_cut_rod_py_d, marker='o', label='memoized_cut_rod_aux')
plt.plot(n, b_cut_rod_py_d, marker='o', label='bottom_up_cut_rod')
plt.yscale('log')
plt.title('python (log scale)')
plt.xlabel('n')
plt.ylabel('duration[ns]')
plt.grid()
plt.legend()
